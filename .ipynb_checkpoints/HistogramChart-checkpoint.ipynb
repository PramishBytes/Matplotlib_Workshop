# %% [markdown]
# ## Histogram Plot
#
# __Syntax:__
#
# import matplotlib.pyplot as plt
#
# x = []
#
# plt.hist(x)
#
# plt.show()
#
# __matplotlib.pyplot.hist(x, bins=None, *, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, data=None, **kwargs)__

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import random

x = np.random.randint(10,60,(50))
print(x)
# Out:
# [46 17 37 49 27 26 33 36 29 43 55 28 16 34 54 42 36 49 34 44 17 49 13 11
#  47 16 16 57 49 53 16 13 31 35 21 16 12 47 46 14 53 49 54 37 27 17 34 37
#  22 56]

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no)

plt.show()b

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no)
plt.title("historgram")
plt.xlabel("python")b
plt.ylabel("No")

plt.show()

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,color = "b")
plt.title("historgram",color="g")
plt.xlabel("python")
plt.ylabel("No")

plt.show()

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,edgecolor="r")
plt.title("historgram")
plt.xlabel("python")
plt.ylabel("No")

plt.show()

# %% [markdown]
# binsint or sequence or str, default: rcParams["hist.bins"] (default: 10)
# If bins is an integer, it defines the number of equal-width bins in the range.
#
# If bins is a sequence, it defines the bin edges, including the left edge of the first bin and the right edge of the last bin; in this case, bins may be unequally spaced. All but the last (righthand-most) bin is half-open. In other words, if bins is:

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,bins =50,edgecolor = "g")
plt.title("historgram")
plt.xlabel("python")
plt.ylabel("No")

plt.show()

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,"auto",edgecolor = "g")
plt.title("historgram")
plt.xlabel("python")
plt.ylabel("No")

plt.show()

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,"auto",edgecolor = "g",cumulative = 1) #cumulativebool or -1, default: False
plt.title("historgram")
plt.xlabel("python")
plt.ylabel("No")

plt.show()

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,"auto",edgecolor = "g",bottom = 10) #bottomarray-like or float, default: 0
plt.title("historgram")
plt.xlabel("python")
plt.ylabel("No")

plt.show()

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,"auto",edgecolor = "g",histtype = "step")
plt.title("historgram")
plt.xlabel("python")
plt.ylabel("No")

plt.show()

# %% [markdown]
# histtype{'bar', 'barstacked', 'step', 'stepfilled'}, default: 'bar'
# The type of histogram to draw.
#
# 'bar' is a traditional bar-type histogram. If multiple data are given the bars are arranged side by side.
#
# 'barstacked' is a bar-type histogram where multiple data are stacked on top of each other.
#
# 'step' generates a lineplot that is by default unfilled.
#
# 'stepfilled' generates a lineplot that is by default filled.

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,"auto",edgecolor = "g",rwidth = 0.8 ) #rwidthfloat or None, default: None
plt.title("historgram")
plt.xlabel("python")
plt.ylabel("No")

plt.show()

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,"auto",edgecolor = "g",label = "python")
plt.title("historgram")
plt.xlabel("python")
plt.ylabel("No")
plt.legend()
plt.show()

# %%
no = [46, 17, 37, 49 ,27 ,26, 33 ,36, 29 ,43, 55 ,28, 16, 34, 54, 42, 36, 49, 34, 44 ,17, 49 ,13 ,11,
 47 ,16, 16, 57, 49 ,53, 16, 13 ,31, 35 ,21, 16 ,12 ,47 ,46 ,14 ,53 ,49 ,54 ,37 ,27, 17 ,34, 37,
 22 ,56]
plt.hist(no,"auto",edgecolor = "g",label = "python",log = True)
plt.title("historgram")
plt.xlabel("python")
plt.ylabel("No")
plt.axvline(45,color="r",label ="line")
plt.legend()
plt.show()
