# %% [markdown]
# ## SubPlot
#
# import matplotlib.pyplot as plt
#
# x =[]
#
# y=[]
#
# plt.subplot(nrows,ncols,index)
#
# plt.plot(x,y)
#
# plt.show()

# %%
import matplotlib.pyplot as plt 
x =[1,2,3,4]

y= [1,2,3,4]

plt.plot(x,y,color= 'r')

plt.show()

# %%
x =[1,2,3,4]

y= [1,2,3,4]
plt.subplot(2,2,1)

plt.plot(x,y,color= 'r')
plt.pie([1],colors = "g")

#x1 = [10,20,30,40]
plt.subplot(2,2,2)
plt.pie(x)

x2 = ["a","s","d","f"]
y2 = [10,20,30,40]
plt.subplot(2,2,3)
plt.bar(x2,y2)

plt.show()
